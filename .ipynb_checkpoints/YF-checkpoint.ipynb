# %%
import yfinance as yf
import pandas as pd
import yfinance as yf
from yahoofinancials import YahooFinancials
# this is the same program lile Cell2, but the difference is the "if" function. Use if to loop 1 value only.
import pandas as pd
import yfinance as yf
from datetime import datetime

# %%
csv_file_path = 'C:/Users/phong/OneDrive/Desktop/usstock/nasdaq_screener.csv'
df = pd.read_csv(csv_file_path)

# %%
#df=df.head(2)
df.head(1)
# Out:
#   Symbol                                    Name Last Sale  Net Change  \
# 0      A  Agilent Technologies Inc. Common Stock  $147.40         2.94
#
#   % Change    Market Cap        Country  IPO Year  Volume       Sector  ...  \
# 0    2.04%  4.319635e+10  United States    1999.0  873678  Industrials  ...
#
#      x                                         x.1  x.2              x.3  \
# 0  url  https://www.macrotrends.net/stocks/charts/    A  /apple/pe-ratio
#
#                                                  url ticker  \
# 0  https://www.macrotrends.net/stocks/charts/A/ap...      A
#
#                                               create  \
# 0  %run C:/Users/phong/OneDrive/Desktop/program/A.py
#
#                                      Unnamed: 20 Unnamed: 21  \
# 0  %run C:/Users/phong/OneDrive/Desktop/program/         .py
#
#                                          Unnamed: 22
# 0  %run C:/Users/phong/OneDrive/Desktop/program/A...
#
# [1 rows x 23 columns]

# %%
#con = df['rank'] > 1070
#con = (df['rank'] > 1070) & (~df['Symbol'].str.contains('/'))
#df = df[con]

import pandas as pd

# Assuming df is your DataFrame

# Check for missing values in 'rank' column
con_missing_rank = df['rank'].isna()

# Check for missing values in 'Symbol' column and if it contains "/"
con_symbol_contains_slash = df['Symbol'].str.contains('/').fillna(False)

# Combine conditions
con = (~con_missing_rank) & (df['rank'] > 1070) & (~con_symbol_contains_slash)

# Apply filtering
df= df[con]

# %%
import os
import pandas as pd
import yfinance as yf
from datetime import datetime

symbols = df['Symbol'].tolist()
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = '1975-01-01'

df_append = []

for ticker in symbols:  # Iterating over symbols list
    df_ticker = yf.download(ticker, start=start_date, end=end_date, progress=False)
    df_ticker['ticker'] = ticker
    df_ticker.reset_index(drop=False, inplace=True)
    df_append.append(df_ticker)

    # Create directory if it doesn't exist
    directory = f'C:/Users/phong/OneDrive/Desktop/usstock/price'
    if not os.path.exists(directory):
        os.makedirs(directory)

    csv_file_path = f'{directory}/{ticker}.csv'
    df_ticker.to_csv(csv_file_path)

df_combined = pd.concat(df_append)
# Out:
# 1 Failed download:
# ['BRKHW']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#
# 1 Failed download:
# ['BRLSW']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#
# 1 Failed download:
# ['BROGW']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#
# 1 Failed download:
# ['BRSHW']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#
# 1 Failed download:
# ['BTBDW']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#
# 1 Failed download:
# ['BTCTW']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#
# 1 Failed download:
# ['BTMWW']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#
# 1 Failed download:
# ['BUJAR']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#
# 1 Failed download:
# ['BW^A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['BWAQR']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#
# 1 Failed download:
# ['BWAQW']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#
# 1 Failed download:
# ['BYNOW']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#
# 1 Failed download:
# ['BZFDW']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#
# 1 Failed download:
# ['C^N']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CADE^A']: Exception('%ticker%: No timezone found, symbol may be delisted')

# %%
# Reset index
#df_combined.reset_index(drop=False, inplace=True)

# %%
df_combined
