# %%
import yfinance as yf
import pandas as pd
import yfinance as yf
from yahoofinancials import YahooFinancials
# this is the same program lile Cell2, but the difference is the "if" function. Use if to loop 1 value only.
import pandas as pd
import yfinance as yf
from datetime import datetime

# %%
csv_file_path = 'C:/Users/phong/OneDrive/Desktop/usstock/nasdaq_screener.csv'
df = pd.read_csv(csv_file_path)

# %%
#df=df.head(2)
df.head(1)
# Out:
#   Symbol                                    Name Last Sale  Net Change  \
# 0      A  Agilent Technologies Inc. Common Stock  $147.40         2.94
#
#   % Change    Market Cap        Country  IPO Year  Volume       Sector  ...  \
# 0    2.04%  4.319635e+10  United States    1999.0  873678  Industrials  ...
#
#      x                                         x.1  x.2              x.3  \
# 0  url  https://www.macrotrends.net/stocks/charts/    A  /apple/pe-ratio
#
#                                                  url ticker  \
# 0  https://www.macrotrends.net/stocks/charts/A/ap...      A
#
#                                               create  \
# 0  %run C:/Users/phong/OneDrive/Desktop/program/A.py
#
#                                      Unnamed: 20 Unnamed: 21  \
# 0  %run C:/Users/phong/OneDrive/Desktop/program/         .py
#
#                                          Unnamed: 22
# 0  %run C:/Users/phong/OneDrive/Desktop/program/A...
#
# [1 rows x 23 columns]

# %%
#con = df['rank'] > 1070
#con = (df['rank'] > 1070) & (~df['Symbol'].str.contains('/'))
#df = df[con]

import pandas as pd

# Assuming df is your DataFrame

# Check for missing values in 'rank' column
con_missing_rank = df['rank'].isna()

# Check for missing values in 'Symbol' column and if it contains "/"
con_symbol_contains_slash = df['Symbol'].str.contains('/').fillna(False)

# Combine conditions
con = (~con_missing_rank) & (df['rank'] > 4405) & (~con_symbol_contains_slash)

# Apply filtering
df= df[con]

# %%
import os
import pandas as pd
import yfinance as yf
from datetime import datetime

# Assuming df is already defined and contains a column 'Symbol'
symbols = df['Symbol'].tolist()

# Filter out non-string symbols
symbols = [symbol for symbol in symbols if isinstance(symbol, str)]

end_date = datetime.today().strftime('%Y-%m-%d')
start_date = '1975-01-01'

df_append = []

for ticker in symbols:  # Iterating over symbols list
    df_ticker = yf.download(ticker, start=start_date, end=end_date, progress=False)
    df_ticker['ticker'] = ticker
    df_ticker.reset_index(drop=False, inplace=True)
    df_append.append(df_ticker)

    # Create directory if it doesn't exist
    directory = f'C:/Users/phong/OneDrive/Desktop/usstock/price'
    if not os.path.exists(directory):
        os.makedirs(directory)

    csv_file_path = f'{directory}/{ticker}.csv'
    df_ticker.to_csv(csv_file_path)

df_combined = pd.concat(df_append)
# Out:
# 1 Failed download:
# ['NCV^A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['NCZ^A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['NEE^N']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['NEE^R']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['NGL^B']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['NGL^C']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['NLY^F']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['NLY^G']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['NLY^I']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ...

# %%
# Reset index
#df_combined.reset_index(drop=False, inplace=True)

# %%
df_combined
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 0    2017-10-20  80.250000  89.300003  80.000000  83.050003  83.050003
# 1    2017-10-23  85.949997  87.485001  73.550003  75.699997  75.699997
# 2    2017-10-24  76.599998  76.599998  67.750000  71.349998  71.349998
# 3    2017-10-25  71.650002  73.250000  55.500000  61.049999  61.049999
# 4    2017-10-26  58.650002  65.599998  58.349998  61.500000  61.500000
# ...         ...        ...        ...        ...        ...        ...
# 5088 2024-05-13  10.490000  10.680000  10.400000  10.680000  10.680000
# 5089 2024-05-14  11.030000  11.030000  10.730000  10.860000  10.860000
# 5090 2024-05-15  11.020000  11.080000  10.890000  11.010000  11.010000
# 5091 2024-05-16  11.010000  11.010000  10.860000  11.000000  11.000000
# 5092 2024-05-17  11.010000  11.010000  10.840000  10.880000  10.880000
#
#          Volume ticker
# 0     2308940.0   NAAS
# 1      517360.0   NAAS
# 2      433220.0   NAAS
# ...
